# %% [markdown]
# <a href="https://colab.research.google.com/github/Ucet786/hello-world/blob/master/Fac_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test_image = cv2.imread('/content/drive/My Drive/IMG-20181203-WA0014 (1).jpg')

test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

plt.imshow(test_image_gray, cmap='gray')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
haar_cascade_face = cv2.CascadeClassifier('/content/drive/My Drive/haarcascade_frontalface_alt2.xml')

# %%
faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor = 1.2, minNeighbors = 5)

# Let us print the no. of faces found
print('Faces found: ', len(faces_rects))
# Out:
# Faces found:  7

# %%
for (x,y,w,h) in faces_rects:
     cv2.rectangle(test_image, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(convertToRGB(test_image))
